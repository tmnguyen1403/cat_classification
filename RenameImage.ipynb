# %%
import os

# %%
t = os.listdir()

# %%
t.sort()

# %%
CAT_TYPE = 'siamese_cat_'
idx = 0
l = len(t)
while idx < l:
    f_name = t[idx]
    new_name = CAT_TYPE + str(idx) + ".jpg"
    os.rename(f_name, new_name)
    idx += 1

# %%
t
# Out:
# ['siamese_cat_0.jpg',
#  'siamese_cat_1.jpg',
#  'siamese_cat_10.jpg',
#  'siamese_cat_100.jpg',
#  'siamese_cat_101.jpg',
#  'siamese_cat_102.jpg',
#  'siamese_cat_103.jpg',
#  'siamese_cat_104.jpg',
#  'siamese_cat_105.jpg',
#  'siamese_cat_106.jpg',
#  'siamese_cat_107.jpg',
#  'siamese_cat_108.jpg',
#  'siamese_cat_109.jpg',
#  'siamese_cat_11.jpg',
#  'siamese_cat_110.jpg',
#  'siamese_cat_111.jpg',
#  'siamese_cat_112.jpg',
#  'siamese_cat_113.jpg',
#  'siamese_cat_114.jpg',
#  'siamese_cat_115.jpg',
#  'siamese_cat_116.jpg',
#  'siamese_cat_117.jpg',
#  'siamese_cat_118.jpg',
#  'siamese_cat_119.jpg',
#  'siamese_cat_12.jpg',
#  'siamese_cat_120.jpg',
#  'siamese_cat_121.jpg',
#  'siamese_cat_122.jpg',
#  'siamese_cat_123.jpg',
#  'siamese_cat_124.jpg',
#  'siamese_cat_125.jpg',
#  'siamese_cat_126.jpg',
#  'siamese_cat_127.jpg',
#  'siamese_cat_128.jpg',
#  'siamese_cat_129.jpg',
#  'siamese_cat_13.jpg',
#  'siamese_cat_130.jpg',
#  'siamese_cat_131.jpg',
# ...
