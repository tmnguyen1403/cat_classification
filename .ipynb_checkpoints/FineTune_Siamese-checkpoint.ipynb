# %%
## ONLY USE FOR COLAB
# memory footprint support libraries/code
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
 process = psutil.Process(os.getpid())
 print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
 print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()

# %%
# !pwd
# Out:
# /content

# %%
#CHECK CUDA VERSION TO GET CORRECT MXNET VERSION
# !env
# Out:
# CUDNN_VERSION=7.6.5.32
# __EGL_VENDOR_LIBRARY_DIRS=/usr/lib64-nvidia:/usr/share/glvnd/egl_vendor.d/
# LD_LIBRARY_PATH=/usr/lib64-nvidia
# _=/usr/bin/env
# LANG=en_US.UTF-8
# HOSTNAME=b8a04e5dc4bd
# OLDPWD=/
# CLOUDSDK_CONFIG=/content/.config
# NVIDIA_VISIBLE_DEVICES=all
# DATALAB_SETTINGS_OVERRIDES={"kernelManagerProxyPort":6000,"kernelManagerProxyHost":"172.28.0.3","jupyterArgs":["--ip=\"172.28.0.2\""]}
# ENV=/root/.bashrc
# PAGER=cat
# NCCL_VERSION=2.4.8
# TF_FORCE_GPU_ALLOW_GROWTH=true
# JPY_PARENT_PID=19
# NO_GCE_CHECK=True
# PWD=/content
# HOME=/root
# LAST_FORCED_REBUILD=20200204
# CLICOLOR=1
# DEBIAN_FRONTEND=noninteractive
# LIBRARY_PATH=/usr/local/cuda/lib64/stubs
# GCE_METADATA_TIMEOUT=0
# GLIBCPP_FORCE_NEW=1
# TBE_CREDS_ADDR=172.28.0.1:8008
# TERM=xterm-color
# SHELL=/bin/bash
# GCS_READ_CACHE_BLOCK_SIZE_MB=16
# PYTHONWARNINGS=ignore:::pip._internal.cli.base_command
# MPLBACKEND=module://ipykernel.pylab.backend_inline
# CUDA_PKG_VERSION=10-1=10.1.243-1
# CUDA_VERSION=10.1.243
# NVIDIA_DRIVER_CAPABILITIES=compute,utility
# SHLVL=2
# PYTHONPATH=/env/python
# NVIDIA_REQUIRE_CUDA=cuda>=10.1 brand=tesla,driver>=384,driver<385 brand=tesla,driver>=396,driver<397 brand=tesla,driver>=410,driver<411
# COLAB_GPU=1
# GLIBCXX_FORCE_NEW=1
# PATH=/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/opt/bin
# LD_PRELOAD=/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4
# GIT_PAGER=cat

# %%
#Using colab
from google.colab import drive

ROOT = '/content/drive'
drive.mount(ROOT)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ROOT = './drive/My Drive/ComputerVision/cat_classification'
# %cd "{ROOT}"
# Out:
# /content/drive/My Drive/ComputerVision/cat_classification

# %%
# !git pull
# Out:
# Updating 767af0b..1f61ef1
# Checking out files: 100% (501/501), done.
# Fast-forward
#  TODO_LOG.ipynb                                     |  31 +++++++++++++++++++++
#  .../cat_test/persian_cat/persian-cat_101.jpg       | Bin 0 -> 44930 bytes
#  .../cat_test/persian_cat/persian-cat_104.jpg       | Bin 0 -> 58412 bytes
#  .../cat_test/persian_cat/persian-cat_105.jpg       | Bin 0 -> 37037 bytes
#  .../cat_test/persian_cat/persian-cat_106.jpg       | Bin 0 -> 37887 bytes
#  .../cat_test/persian_cat/persian-cat_110.jpg       | Bin 0 -> 59070 bytes
#  .../cat_test/persian_cat/persian-cat_111.jpg       | Bin 0 -> 42013 bytes
#  .../cat_test/persian_cat/persian-cat_112.jpg       | Bin 0 -> 53251 bytes
#  .../cat_test/persian_cat/persian-cat_115.jpg       | Bin 0 -> 63065 bytes
#  .../cat_test/persian_cat/persian-cat_129.jpg       | Bin 0 -> 42135 bytes
#  .../cat_test/persian_cat/persian-cat_138.jpg       | Bin 0 -> 49859 bytes
#  .../cat_test/persian_cat/persian-cat_139.jpg       | Bin 0 -> 59221 bytes
#  .../images/cat_test/persian_cat/persian-cat_18.jpg | Bin 0 -> 39862 bytes
#  .../images/cat_test/persian_cat/persian-cat_19.jpg | Bin 0 -> 56264 bytes
#  .../images/cat_test/persian_cat/persian-cat_24.jpg | Bin 0 -> 46895 bytes
#  .../images/cat_test/persian_cat/persian-cat_25.jpg | Bin 0 -> 66718 bytes
#  .../cat_test/persian_cat/persian-cat_258.jpg       | Bin 0 -> 48453 bytes
#  .../images/cat_test/persian_cat/persian-cat_26.jpg | Bin 0 -> 44348 bytes
#  .../cat_test/persian_cat/persian-cat_264.jpg       | Bin 0 -> 51817 bytes
#  .../cat_test/persian_cat/persian-cat_266.jpg       | Bin 0 -> 48262 bytes
#  .../cat_test/persian_cat/persian-cat_267.jpg       | Bin 0 -> 43926 bytes
#  .../images/cat_test/persian_cat/persian-cat_27.jpg | Bin 0 -> 40403 bytes
#  .../cat_test/persian_cat/persian-cat_270.jpg       | Bin 0 -> 33059 bytes
#  .../cat_test/persian_cat/persian-cat_272.jpg       | Bin 0 -> 32685 bytes
#  .../cat_test/persian_cat/persian-cat_273.jpg       | Bin 0 -> 53668 bytes
#  .../cat_test/persian_cat/persian-cat_298.jpg       | Bin 0 -> 108458 bytes
#  .../cat_test/persian_cat/persian-cat_299.jpg       | Bin 0 -> 14105 bytes
#  .../images/cat_test/persian_cat/persian-cat_30.jpg | Bin 0 -> 40433 bytes
#  .../cat_test/persian_cat/persian-cat_303.jpg       | Bin 0 -> 80010 bytes
#  .../cat_test/persian_cat/persian-cat_304.jpg       | Bin 0 -> 50306 bytes
#  .../cat_test/persian_cat/persian-cat_306.jpg       | Bin 0 -> 49658 bytes
#  .../cat_test/persian_cat/persian-cat_307.jpg       | Bin 0 -> 68404 bytes
#  .../cat_test/persian_cat/persian-cat_310.jpg       | Bin 0 -> 55322 bytes
#  .../cat_test/persian_cat/persian-cat_312.jpg       | Bin 0 -> 52418 bytes
#  .../cat_test/persian_cat/persian-cat_313.jpg       | Bin 0 -> 48300 bytes
#  .../cat_test/persian_cat/persian-cat_317.jpg       | Bin 0 -> 36115 bytes
#  .../images/cat_test/persian_cat/persian-cat_32.jpg | Bin 0 -> 118801 bytes
#  .../images/cat_test/persian_cat/persian-cat_33.jpg | Bin 0 -> 42891 bytes
#  .../cat_test/persian_cat/persian-cat_338.jpg       | Bin 0 -> 48054 bytes
#  .../cat_test/persian_cat/persian-cat_448.jpg       | Bin 0 -> 20020 bytes
#  .../cat_test/persian_cat/persian-cat_449.jpg       | Bin 0 -> 7819 bytes
#  .../cat_test/persian_cat/persian-cat_459.jpg       | Bin 0 -> 42676 bytes
#  .../cat_test/persian_cat/persian-cat_460.jpg       | Bin 0 -> 53108 bytes
#  .../cat_test/persian_cat/persian-cat_461.jpg       | Bin 0 -> 75231 bytes
#  .../cat_test/persian_cat/persian-cat_462.jpg       | Bin 0 -> 41172 bytes
#  .../cat_test/persian_cat/persian-cat_465.jpg       | Bin 0 -> 65325 bytes
#  .../cat_test/persian_cat/persian-cat_471.jpg       | Bin 0 -> 37676 bytes
#  .../cat_test/persian_cat/persian-cat_474.jpg       | Bin 0 -> 95316 bytes
#  .../cat_test/persian_cat/persian-cat_475.jpg       | Bin 0 -> 67178 bytes
#  .../cat_test/persian_cat/persian-cat_476.jpg       | Bin 0 -> 69520 bytes
#  .../cat_test/persian_cat/persian-cat_489.jpg       | Bin 0 -> 35303 bytes
#  .../cat_test/persian_cat/persian-cat_500.jpg       | Bin 0 -> 55864 bytes
#  .../cat_test/persian_cat/persian-cat_501.jpg       | Bin 0 -> 52346 bytes
#  .../cat_test/persian_cat/persian-cat_502.jpg       | Bin 0 -> 41493 bytes
#  .../cat_test/persian_cat/persian-cat_514.jpg       | Bin 0 -> 58740 bytes
#  .../cat_test/persian_cat/persian-cat_515.jpg       | Bin 0 -> 63840 bytes
#  .../cat_test/persian_cat/persian-cat_516.jpg       | Bin 0 -> 31303 bytes
#  .../cat_test/persian_cat/persian-cat_528.jpg       | Bin 0 -> 28101 bytes
#  .../cat_test/persian_cat/persian-cat_529.jpg       | Bin 0 -> 59490 bytes
#  .../cat_test/persian_cat/persian-cat_648.jpg       | Bin 0 -> 51063 bytes
#  .../cat_test/persian_cat/persian-cat_660.jpg       | Bin 0 -> 43175 bytes
#  .../cat_test/persian_cat/persian-cat_662.jpg       | Bin 0 -> 62276 bytes
#  .../cat_test/persian_cat/persian-cat_663.jpg       | Bin 0 -> 89277 bytes
#  .../cat_test/persian_cat/persian-cat_667.jpg       | Bin 0 -> 36262 bytes
#  .../cat_test/persian_cat/persian-cat_673.jpg       | Bin 0 -> 43284 bytes
#  .../cat_test/persian_cat/persian-cat_674.jpg       | Bin 0 -> 35776 bytes
#  .../cat_test/persian_cat/persian-cat_676.jpg       | Bin 0 -> 51944 bytes
#  .../cat_test/persian_cat/persian-cat_677.jpg       | Bin 0 -> 68378 bytes
#  .../cat_test/persian_cat/persian-cat_689.jpg       | Bin 0 -> 34693 bytes
#  .../cat_test/persian_cat/persian-cat_698.jpg       | Bin 0 -> 36578 bytes
#  .../cat_test/persian_cat/persian-cat_700.jpg       | Bin 0 -> 39226 bytes
#  .../cat_test/persian_cat/persian-cat_702.jpg       | Bin 0 -> 64549 bytes
#  .../cat_test/persian_cat/persian-cat_703.jpg       | Bin 0 -> 48849 bytes
#  .../cat_test/persian_cat/persian-cat_714.jpg       | Bin 0 -> 44179 bytes
#  .../cat_test/persian_cat/persian-cat_716.jpg       | Bin 0 -> 40612 bytes
#  .../cat_test/persian_cat/persian-cat_717.jpg       | Bin 0 -> 60840 bytes
#  .../cat_test/persian_cat/persian-cat_728.jpg       | Bin 0 -> 42333 bytes
#  .../cat_test/persian_cat/persian-cat_844.jpg       | Bin 0 -> 45882 bytes
#  .../cat_test/persian_cat/persian-cat_845.jpg       | Bin 0 -> 103616 bytes
#  .../cat_test/persian_cat/persian-cat_847.jpg       | Bin 0 -> 104638 bytes
#  .../cat_test/persian_cat/persian-cat_850.jpg       | Bin 0 -> 62480 bytes
#  .../cat_test/persian_cat/persian-cat_851.jpg       | Bin 0 -> 82745 bytes
#  .../cat_test/persian_cat/persian-cat_853.jpg       | Bin 0 -> 43024 bytes
#  .../cat_test/persian_cat/persian-cat_878.jpg       | Bin 0 -> 61660 bytes
#  .../cat_test/persian_cat/persian-cat_879.jpg       | Bin 0 -> 38035 bytes
#  .../cat_test/persian_cat/persian-cat_883.jpg       | Bin 0 -> 48207 bytes
#  .../cat_test/persian_cat/persian-cat_884.jpg       | Bin 0 -> 45366 bytes
#  .../cat_test/persian_cat/persian-cat_886.jpg       | Bin 0 -> 74404 bytes
#  .../cat_test/persian_cat/persian-cat_887.jpg       | Bin 0 -> 73461 bytes
#  .../cat_test/persian_cat/persian-cat_890.jpg       | Bin 0 -> 46174 bytes
#  .../cat_test/persian_cat/persian-cat_892.jpg       | Bin 0 -> 54026 bytes
#  .../cat_test/persian_cat/persian-cat_893.jpg       | Bin 0 -> 48044 bytes
#  .../cat_test/persian_cat/persian-cat_897.jpg       | Bin 0 -> 87794 bytes
#  .../cat_test/persian_cat/persian-cat_918.jpg       | Bin 0 -> 35015 bytes
#  .../cat_test/persian_cat/persian-cat_919.jpg       | Bin 0 -> 44665 bytes
#  .../cat_test/persian_cat/persian-cat_924.jpg       | Bin 0 -> 50642 bytes
#  .../cat_test/persian_cat/persian-cat_925.jpg       | Bin 0 -> 45429 bytes
#  .../cat_test/persian_cat/persian-cat_927.jpg       | Bin 0 -> 36899 bytes
#  .../cat_test/persian_cat/persian-cat_930.jpg       | Bin 0 -> 57299 bytes
#  .../cat_test/persian_cat/persian-cat_931.jpg       | Bin 0 -> 53854 bytes
#  .../cat_test/persian_cat/persian-cat_933.jpg       | Bin 0 -> 42659 bytes
#  .../images/cat_train/persian_cat/persian-cat_0.jpg | Bin 0 -> 39767 bytes
#  .../images/cat_train/persian_cat/persian-cat_1.jpg | Bin 0 -> 65459 bytes
#  .../cat_train/persian_cat/persian-cat_159.jpg      | Bin 0 -> 28560 bytes
#  .../cat_train/persian_cat/persian-cat_162.jpg      | Bin 0 -> 36546 bytes
#  .../cat_train/persian_cat/persian-cat_165.jpg      | Bin 0 -> 43739 bytes
#  .../cat_train/persian_cat/persian-cat_166.jpg      | Bin 0 -> 68954 bytes
#  .../cat_train/persian_cat/persian-cat_167.jpg      | Bin 0 -> 34627 bytes
#  .../cat_train/persian_cat/persian-cat_171.jpg      | Bin 0 -> 43302 bytes
#  .../cat_train/persian_cat/persian-cat_172.jpg      | Bin 0 -> 76892 bytes
#  .../cat_train/persian_cat/persian-cat_173.jpg      | Bin 0 -> 50402 bytes
#  .../cat_train/persian_cat/persian-cat_176.jpg      | Bin 0 -> 46065 bytes
#  .../cat_train/persian_cat/persian-cat_189.jpg      | Bin 0 -> 50685 bytes
#  .../cat_train/persian_cat/persian-cat_198.jpg      | Bin 0 -> 65381 bytes
#  .../cat_train/persian_cat/persian-cat_199.jpg      | Bin 0 -> 34248 bytes
#  .../cat_train/persian_cat/persian-cat_204.jpg      | Bin 0 -> 53316 bytes
#  .../cat_train/persian_cat/persian-cat_205.jpg      | Bin 0 -> 62542 bytes
#  .../cat_train/persian_cat/persian-cat_210.jpg      | Bin 0 -> 48731 bytes
#  .../cat_train/persian_cat/persian-cat_211.jpg      | Bin 0 -> 51419 bytes
#  .../cat_train/persian_cat/persian-cat_214.jpg      | Bin 0 -> 69993 bytes
#  .../cat_train/persian_cat/persian-cat_228.jpg      | Bin 0 -> 47099 bytes
#  .../cat_train/persian_cat/persian-cat_238.jpg      | Bin 0 -> 54228 bytes
#  .../cat_train/persian_cat/persian-cat_239.jpg      | Bin 0 -> 32882 bytes
#  .../cat_train/persian_cat/persian-cat_348.jpg      | Bin 0 -> 45165 bytes
#  .../cat_train/persian_cat/persian-cat_358.jpg      | Bin 0 -> 34933 bytes
#  .../cat_train/persian_cat/persian-cat_359.jpg      | Bin 0 -> 27060 bytes
#  .../cat_train/persian_cat/persian-cat_360.jpg      | Bin 0 -> 40746 bytes
#  .../cat_train/persian_cat/persian-cat_364.jpg      | Bin 0 -> 49253 bytes
#  .../cat_train/persian_cat/persian-cat_365.jpg      | Bin 0 -> 53270 bytes
#  .../cat_train/persian_cat/persian-cat_367.jpg      | Bin 0 -> 36398 bytes
#  .../cat_train/persian_cat/persian-cat_370.jpg      | Bin 0 -> 48206 bytes
#  .../cat_train/persian_cat/persian-cat_371.jpg      | Bin 0 -> 51771 bytes
#  .../cat_train/persian_cat/persian-cat_373.jpg      | Bin 0 -> 70076 bytes
#  .../cat_train/persian_cat/persian-cat_374.jpg      | Bin 0 -> 39983 bytes
#  .../cat_train/persian_cat/persian-cat_398.jpg      | Bin 0 -> 38458 bytes
#  .../cat_train/persian_cat/persian-cat_401.jpg      | Bin 0 -> 40207 bytes
#  .../cat_train/persian_cat/persian-cat_402.jpg      | Bin 0 -> 45780 bytes
#  .../cat_train/persian_cat/persian-cat_403.jpg      | Bin 0 -> 69730 bytes
#  .../cat_train/persian_cat/persian-cat_406.jpg      | Bin 0 -> 36167 bytes
#  .../cat_train/persian_cat/persian-cat_412.jpg      | Bin 0 -> 51353 bytes
#  .../cat_train/persian_cat/persian-cat_415.jpg      | Bin 0 -> 88257 bytes
#  .../cat_train/persian_cat/persian-cat_416.jpg      | Bin 0 -> 62243 bytes
#  .../cat_train/persian_cat/persian-cat_417.jpg      | Bin 0 -> 59452 bytes
#  .../cat_train/persian_cat/persian-cat_429.jpg      | Bin 0 -> 57040 bytes
#  .../cat_train/persian_cat/persian-cat_44.jpg       | Bin 0 -> 20553 bytes
#  .../cat_train/persian_cat/persian-cat_45.jpg       | Bin 0 -> 37572 bytes
#  .../images/cat_train/persian_cat/persian-cat_5.jpg | Bin 0 -> 49303 bytes
#  .../cat_train/persian_cat/persian-cat_50.jpg       | Bin 0 -> 38498 bytes
#  .../cat_train/persian_cat/persian-cat_51.jpg       | Bin 0 -> 48087 bytes
#  .../cat_train/persian_cat/persian-cat_562.jpg      | Bin 0 -> 60384 bytes
#  .../cat_train/persian_cat/persian-cat_563.jpg      | Bin 0 -> 95982 bytes
#  .../cat_train/persian_cat/persian-cat_572.jpg      | Bin 0 -> 45057 bytes
#  .../cat_train/persian_cat/persian-cat_576.jpg      | Bin 0 -> 37645 bytes
#  .../cat_train/persian_cat/persian-cat_577.jpg      | Bin 0 -> 58873 bytes
#  .../cat_train/persian_cat/persian-cat_588.jpg      | Bin 0 -> 42325 bytes
#  .../cat_train/persian_cat/persian-cat_589.jpg      | Bin 0 -> 53400 bytes
#  .../cat_train/persian_cat/persian-cat_600.jpg      | Bin 0 -> 68109 bytes
#  .../cat_train/persian_cat/persian-cat_601.jpg      | Bin 0 -> 15121 bytes
#  .../cat_train/persian_cat/persian-cat_603.jpg      | Bin 0 -> 40206 bytes
#  .../cat_train/persian_cat/persian-cat_604.jpg      | Bin 0 -> 33128 bytes
#  .../cat_train/persian_cat/persian-cat_610.jpg      | Bin 0 -> 45355 bytes
#  .../cat_train/persian_cat/persian-cat_614.jpg      | Bin 0 -> 25889 bytes
#  .../cat_train/persian_cat/persian-cat_615.jpg      | Bin 0 -> 100083 bytes
#  .../cat_train/persian_cat/persian-cat_617.jpg      | Bin 0 -> 48684 bytes
#  .../cat_train/persian_cat/persian-cat_628.jpg      | Bin 0 -> 44789 bytes
#  .../cat_train/persian_cat/persian-cat_629.jpg      | Bin 0 -> 72560 bytes
#  .../cat_train/persian_cat/persian-cat_638.jpg      | Bin 0 -> 70266 bytes
#  .../cat_train/persian_cat/persian-cat_748.jpg      | Bin 0 -> 48769 bytes
#  .../cat_train/persian_cat/persian-cat_749.jpg      | Bin 0 -> 26145 bytes
#  .../cat_train/persian_cat/persian-cat_758.jpg      | Bin 0 -> 40348 bytes
#  .../cat_train/persian_cat/persian-cat_760.jpg      | Bin 0 -> 15318 bytes
#  .../cat_train/persian_cat/persian-cat_761.jpg      | Bin 0 -> 30724 bytes
#  .../cat_train/persian_cat/persian-cat_764.jpg      | Bin 0 -> 36327 bytes
#  .../cat_train/persian_cat/persian-cat_770.jpg      | Bin 0 -> 52406 bytes
#  .../cat_train/persian_cat/persian-cat_774.jpg      | Bin 0 -> 46328 bytes
#  .../cat_train/persian_cat/persian-cat_775.jpg      | Bin 0 -> 49277 bytes
#  .../cat_train/persian_cat/persian-cat_78.jpg       | Bin 0 -> 51645 bytes
#  .../cat_train/persian_cat/persian-cat_79.jpg       | Bin 0 -> 51721 bytes
#  .../cat_train/persian_cat/persian-cat_818.jpg      | Bin 0 -> 47197 bytes
#  .../cat_train/persian_cat/persian-cat_823.jpg      | Bin 0 -> 45529 bytes
#  .../cat_train/persian_cat/persian-cat_826.jpg      | Bin 0 -> 57752 bytes
#  .../cat_train/persian_cat/persian-cat_827.jpg      | Bin 0 -> 24740 bytes
#  .../cat_train/persian_cat/persian-cat_83.jpg       | Bin 0 -> 45784 bytes
#  .../cat_train/persian_cat/persian-cat_832.jpg      | Bin 0 -> 89552 bytes
#  .../cat_train/persian_cat/persian-cat_833.jpg      | Bin 0 -> 43507 bytes
#  .../cat_train/persian_cat/persian-cat_837.jpg      | Bin 0 -> 48301 bytes
#  .../cat_train/persian_cat/persian-cat_86.jpg       | Bin 0 -> 47627 bytes
#  .../cat_train/persian_cat/persian-cat_87.jpg       | Bin 0 -> 39899 bytes
#  .../cat_train/persian_cat/persian-cat_92.jpg       | Bin 0 -> 48031 bytes
#  .../cat_train/persian_cat/persian-cat_93.jpg       | Bin 0 -> 80278 bytes
#  .../cat_train/persian_cat/persian-cat_943.jpg      | Bin 0 -> 61044 bytes
#  .../cat_train/persian_cat/persian-cat_946.jpg      | Bin 0 -> 68498 bytes
#  .../cat_train/persian_cat/persian-cat_947.jpg      | Bin 0 -> 49219 bytes
#  .../cat_train/persian_cat/persian-cat_952.jpg      | Bin 0 -> 66492 bytes
#  .../cat_train/persian_cat/persian-cat_953.jpg      | Bin 0 -> 40598 bytes
#  .../cat_train/persian_cat/persian-cat_957.jpg      | Bin 0 -> 58993 bytes
#  .../cat_train/persian_cat/persian-cat_980.jpg      | Bin 0 -> 61850 bytes
#  .../cat_train/persian_cat/persian-cat_984.jpg      | Bin 0 -> 75336 bytes
#  .../cat_train/persian_cat/persian-cat_985.jpg      | Bin 0 -> 54738 bytes
#  .../cat_train/persian_cat/persian-cat_990.jpg      | Bin 0 -> 46539 bytes
#  .../cat_train/persian_cat/persian-cat_991.jpg      | Bin 0 -> 72189 bytes
#  .../images/cat_val/persian_cat/persian-cat_158.jpg | Bin 0 -> 33808 bytes
#  .../images/cat_val/persian_cat/persian-cat_164.jpg | Bin 0 -> 44353 bytes
#  .../images/cat_val/persian_cat/persian-cat_170.jpg | Bin 0 -> 39134 bytes
#  data/images/cat_val/persian_cat/persian-cat_2.jpg  | Bin 0 -> 46996 bytes
#  .../images/cat_val/persian_cat/persian-cat_206.jpg | Bin 0 -> 37974 bytes
#  .../images/cat_val/persian_cat/persian-cat_207.jpg | Bin 0 -> 64060 bytes
#  .../images/cat_val/persian_cat/persian-cat_212.jpg | Bin 0 -> 101163 bytes
#  .../images/cat_val/persian_cat/persian-cat_213.jpg | Bin 0 -> 57673 bytes
#  data/images/cat_val/persian_cat/persian-cat_3.jpg  | Bin 0 -> 35960 bytes
#  .../images/cat_val/persian_cat/persian-cat_366.jpg | Bin 0 -> 38680 bytes
#  .../images/cat_val/persian_cat/persian-cat_399.jpg | Bin 0 -> 32978 bytes
#  .../images/cat_val/persian_cat/persian-cat_400.jpg | Bin 0 -> 56751 bytes
#  .../images/cat_val/persian_cat/persian-cat_414.jpg | Bin 0 -> 41715 bytes
#  .../images/cat_val/persian_cat/persian-cat_428.jpg | Bin 0 -> 58470 bytes
#  data/images/cat_val/persian_cat/persian-cat_46.jpg | Bin 0 -> 39663 bytes
#  data/images/cat_val/persian_cat/persian-cat_47.jpg | Bin 0 -> 48486 bytes
#  data/images/cat_val/persian_cat/persian-cat_52.jpg | Bin 0 -> 72643 bytes
#  data/images/cat_val/persian_cat/persian-cat_53.jpg | Bin 0 -> 41565 bytes
#  .../images/cat_val/persian_cat/persian-cat_548.jpg | Bin 0 -> 44820 bytes
#  .../images/cat_val/persian_cat/persian-cat_549.jpg | Bin 0 -> 28476 bytes
#  .../images/cat_val/persian_cat/persian-cat_560.jpg | Bin 0 -> 51947 bytes
#  .../images/cat_val/persian_cat/persian-cat_561.jpg | Bin 0 -> 32807 bytes
#  .../images/cat_val/persian_cat/persian-cat_574.jpg | Bin 0 -> 41582 bytes
#  .../images/cat_val/persian_cat/persian-cat_575.jpg | Bin 0 -> 54373 bytes
#  .../images/cat_val/persian_cat/persian-cat_602.jpg | Bin 0 -> 35215 bytes
#  .../images/cat_val/persian_cat/persian-cat_616.jpg | Bin 0 -> 49479 bytes
#  .../images/cat_val/persian_cat/persian-cat_762.jpg | Bin 0 -> 51189 bytes
#  .../images/cat_val/persian_cat/persian-cat_763.jpg | Bin 0 -> 42567 bytes
#  .../images/cat_val/persian_cat/persian-cat_776.jpg | Bin 0 -> 56645 bytes
#  .../images/cat_val/persian_cat/persian-cat_777.jpg | Bin 0 -> 73031 bytes
#  .../images/cat_val/persian_cat/persian-cat_788.jpg | Bin 0 -> 48670 bytes
#  .../images/cat_val/persian_cat/persian-cat_789.jpg | Bin 0 -> 48988 bytes
#  .../images/cat_val/persian_cat/persian-cat_819.jpg | Bin 0 -> 43733 bytes
#  .../images/cat_val/persian_cat/persian-cat_824.jpg | Bin 0 -> 27768 bytes
#  .../images/cat_val/persian_cat/persian-cat_825.jpg | Bin 0 -> 45776 bytes
#  .../images/cat_val/persian_cat/persian-cat_830.jpg | Bin 0 -> 75666 bytes
#  .../images/cat_val/persian_cat/persian-cat_831.jpg | Bin 0 -> 62659 bytes
#  data/images/cat_val/persian_cat/persian-cat_84.jpg | Bin 0 -> 3402 bytes
#  data/images/cat_val/persian_cat/persian-cat_85.jpg | Bin 0 -> 41494 bytes
#  data/images/cat_val/persian_cat/persian-cat_90.jpg | Bin 0 -> 61546 bytes
#  data/images/cat_val/persian_cat/persian-cat_91.jpg | Bin 0 -> 52189 bytes
#  .../images/cat_val/persian_cat/persian-cat_944.jpg | Bin 0 -> 54399 bytes
#  .../images/cat_val/persian_cat/persian-cat_945.jpg | Bin 0 -> 23196 bytes
#  .../images/cat_val/persian_cat/persian-cat_950.jpg | Bin 0 -> 22272 bytes
#  .../images/cat_val/persian_cat/persian-cat_951.jpg | Bin 0 -> 39778 bytes
#  .../images/cat_val/persian_cat/persian-cat_978.jpg | Bin 0 -> 45986 bytes
#  .../images/cat_val/persian_cat/persian-cat_979.jpg | Bin 0 -> 39349 bytes
#  .../images/cat_val/persian_cat/persian-cat_986.jpg | Bin 0 -> 55146 bytes
#  .../images/cat_val/persian_cat/persian-cat_987.jpg | Bin 0 -> 57992 bytes
#  .../images/cat_val/persian_cat/persian-cat_992.jpg | Bin 0 -> 51402 bytes
#  .../cat_test/persian_cat/persian-cat_10.jpg        | Bin 61567 -> 0 bytes
#  .../cat_test/persian_cat/persian-cat_108.jpg       | Bin 54009 -> 0 bytes
#  .../cat_test/persian_cat/persian-cat_11.jpg        | Bin 46841 -> 0 bytes
#  .../cat_test/persian_cat/persian-cat_118.jpg       | Bin 58136 -> 0 bytes
#  .../cat_test/persian_cat/persian-cat_119.jpg       | Bin 67706 -> 0 bytes
#  .../cat_test/persian_cat/persian-cat_12.jpg        | Bin 63567 -> 0 bytes
#  .../cat_test/persian_cat/persian-cat_120.jpg       | Bin 57637 -> 0 bytes
#  .../cat_test/persian_cat/persian-cat_124.jpg       | Bin 65082 -> 0 bytes
#  .../cat_test/persian_cat/persian-cat_125.jpg       | Bin 55115 -> 0 bytes
#  .../cat_test/persian_cat/persian-cat_126.jpg       | Bin 38610 -> 0 bytes
#  .../cat_test/persian_cat/persian-cat_127.jpg       | Bin 58620 -> 0 bytes
#  .../cat_test/persian_cat/persian-cat_13.jpg        | Bin 67595 -> 0 bytes
#  .../cat_test/persian_cat/persian-cat_130.jpg       | Bin 45608 -> 0 bytes
#  .../cat_test/persian_cat/persian-cat
jpg
#  delete mode 100644 image_net_data/cat_test/persian_cat/persian-cat_38.jpg
#  delete mode 100644 image_net_data/cat_test/persian_cat/persian-cat_380.jpg
#  delete mode 100644 image_net_data/cat_test/persian_cat/persian-cat_381.jpg
#  delete mode 100644 image_net_data/cat_test/persian_cat/persian-cat_383.jpg
#  delete mode 100644 image_net_data/cat_test/persian_cat/persian-cat_39.jpg
#  delete mode 100644 image_net_data/cat_test/persian_cat/persian-cat_394.jpg
#  delete mode 100644 image_net_data/cat_test/persian_cat/persian-cat_395.jpg
#  delete mode 100644 image_net_data/cat_test/persian_cat/persian-cat_397.jpg
#  delete mode 100644 image_net_data/cat_test/persian_cat/persian-cat_418.jpg
#  delete mode 100644 image_net_data/cat_test/persian_cat/persian-cat_419.jpg
#  delete mode 100644 image_net_data/cat_test/persian_cat/persian-cat_48.jpg
#  delete mode 100644 image_net_data/cat_test/persian_cat/persian-cat_49.jpg
#  delete mode 100644 image_net_data/cat_test/persian_cat/persian-cat_60.jpg
#  delete mode 100644 image_net_data/cat_test/persian_cat/persian-cat_61.jpg
#  delete mode 100644 image_net_data/cat_test/persian_cat/persian-cat_62.jpg
#  delete mode 100644 image_net_data/cat_test/persian_cat/persian-cat_63.jpg
#  delete mode 100644 image_net_data/cat_test/persian_cat/persian-cat_74.jpg
#  delete mode 100644 image_net_data/cat_test/persian_cat/persian-cat_75.jpg
#  delete mode 100644 image_net_data/cat_test/persian_cat/persian-cat_76.jpg
#  delete mode 100644 image_net_data/cat_test/persian_cat/persian-cat_77.jpg
#  delete mode 100644 image_net_data/cat_test/persian_cat/persian-cat_88.jpg
#  delete mode 100644 image_net_data/cat_test/persian_cat/persian-cat_89.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_0.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_1.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_148.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_149.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_160.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_161.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_162.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_163.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_166.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_167.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_172.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_173.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_174.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_175.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_176.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_177.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_188.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_189.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_198.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_199.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_200.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_201.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_202.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_203.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_204.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_205.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_210.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_211.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_214.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_215.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_216.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_217.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_228.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_229.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_238.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_239.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_348.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_349.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_358.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_359.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_360.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_361.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_362.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_363.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_364.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_365.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_370.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_371.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_373.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_374.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_375.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_376.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_377.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_388.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_389.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_4.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_40.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_402.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_403.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_404.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_405.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_406.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_407.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_41.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_410.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_411.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_412.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_413.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_415.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_416.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_417.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_42.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_43.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_44.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_45.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_5.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_50.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_51.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_54.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_55.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_56.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_57.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_6.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_68.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_69.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_7.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_78.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_79.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_80.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_81.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_82.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_83.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_86.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_87.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_92.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_93.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_94.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_95.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_96.jpg
#  delete mode 100644 image_net_data/cat_train/persian_cat/persian-cat_97.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_102.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_103.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_116.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_117.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_158.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_159.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_164.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_165.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_170.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_171.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_2.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_20.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_206.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_207.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_21.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_212.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_213.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_248.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_249.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_260.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_261.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_274.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_275.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_3.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_300.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_301.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_302.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_314.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_315.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_316.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_328.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_329.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_34.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_35.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_366.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_367.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_372.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_398.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_399.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_400.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_401.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_414.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_46.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_47.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_52.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_53.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_84.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_85.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_90.jpg
#  delete mode 100644 image_net_data/cat_val/persian_cat/persian-cat_91.jpg

# %%
# %ls data/images/cat_test/
# Out:
# bengal_cat/  munchkin_cat/  persian_cat/  siamese_cat/

# %%
##ONLY USE FOR COLAB OR Computer with GPU(s)
# !pip install -q mxnet-cu100 gluoncv

#NO GPU(s)
#!pip install mxnet gluoncv
# Out:
#      |████████████████████████████████| 540.1MB 31kB/s
#      |████████████████████████████████| 696kB 63.3MB/s

# %% [markdown]
# # New Section

# %%
import os
import time
import mxnet as mx
import numpy as np

from mxnet import gluon, image, init, nd
from mxnet import autograd
from mxnet.gluon import nn
from mxnet.gluon.data.vision import transforms
from mxnet.gluon.data.vision import ImageFolderDataset
from gluoncv.utils import makedirs
from gluoncv.model_zoo import get_model
from matplotlib import pyplot as plt

# %%
#Data Description
#Train Data: 100 images
#Val Data: 50 images
#Classes: Bengal and Siamese cat
# + Munchkin

# %%
#Hypterparameters
classes = 4
epochs = 12
lr = 0.001
momentum = 0.9
wd = 0.0001
num_gpus = 1
num_workers = 4
per_device_batch_size = 10
ctx = [mx.gpu(i) for i in range(num_gpus)] if num_gpus > 0 else [mx.cpu()]
batch_size = per_device_batch_size * max(num_gpus, 1)

# %%
#Data Augmentation
jitter_param = 0.4
lighting_param = 0.1

transform_train = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomFlipLeftRight(),
    transforms.RandomColorJitter(brightness=jitter_param, contrast=jitter_param, saturation=jitter_param),
    transforms.RandomLighting(lighting_param),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, .0225])
])

transform_test = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, .0225])
])

# %%
path = './data/images'
test_path = './data/images'
train_path = os.path.join(path, 'cat_train')
val_path = os.path.join(path, 'cat_val')
test_path = os.path.join(path, 'cat_test')

train_data = gluon.data.DataLoader(
    ImageFolderDataset(train_path).transform_first(transform_train),
    batch_size=batch_size, shuffle=True
)

val_data = gluon.data.DataLoader(
    ImageFolderDataset(val_path).transform_first(transform_test),
    batch_size=batch_size, shuffle=False
)

test_data = gluon.data.DataLoader(
    ImageFolderDataset(test_path).transform_first(transform_test),
    batch_size=batch_size
)

# %%
#Load Resnet
model_name = 'ResNet50_v2'
finetune_net = get_model(model_name, pretrained = True)

#Redefine output layer
with finetune_net.name_scope():
    finetune_net.output = nn.Dense(classes)
finetune_net.output.initialize(init.Xavier(), ctx=ctx)
finetune_net.collect_params().reset_ctx(ctx)
finetune_net.hybridize()

#Since I already trained the model, I only need to load it

# %%
#Load trained model
# CURRENT_TRAIN = 'resnet-0012.params'
# SAVE_PATH ='./Params_Save'
# model_path = os.path.join(SAVE_PATH, 'resnet-symbol.json')
# param_path = os.path.join(SAVE_PATH, CURRENT_TRAIN)
# import warnings
# with warnings.catch_warnings():
#     warnings.simplefilter("ignore")
#     finetune_net = gluon.nn.SymbolBlock.imports(model_path, ['data'], param_path, ctx=ctx)

# %%
trainer = gluon.Trainer(finetune_net.collect_params(), 'sgd', {
    'learning_rate': lr, 'momentum': momentum, 'wd': wd
})

metric = mx.metric.Accuracy()
loss_fn = gluon.loss.SoftmaxCrossEntropyLoss()

# %%
#Test
def test(net, val_data, ctx):
    metric = mx.metric.Accuracy()
    for i, batch in enumerate(val_data):
        data = gluon.utils.split_and_load(batch[0], ctx_list=ctx, batch_axis=0, even_split=False)
        label = gluon.utils.split_and_load(batch[1], ctx_list=ctx, batch_axis=0, even_split=False)
        outputs = [net(X) for X in data]
        metric.update(label, outputs)
    return metric.get()

# %%
def save_model(net, epoch, path = './trained_models', name ='resnet'):
  f_name = os.path.join(path, name)
  net.export(f_name, epoch=epoch)

# %%
#Training loop
num_batch = len(train_data)
train_history = []
early_stop = 3
early_count = 0
stop_threshold = -0.01
for epoch in range(epochs):
    tic = time.time()
    train_loss = 0
    metric.reset()
    
    for i, batch in enumerate(train_data):
        data = gluon.utils.split_and_load(batch[0], ctx_list=ctx, batch_axis=0, even_split=False)
        label = gluon.utils.split_and_load(batch[1], ctx_list=ctx, batch_axis=0, even_split=False)
        with autograd.record():
            outputs = [finetune_net(X) for X in data]
            loss = [loss_fn(yhat, y) for yhat, y in zip(outputs, label)]
        for l in loss:
            l.backward()
        trainer.step(batch_size)
        train_loss += sum([l.mean().asscalar() for l in loss]) / len(loss)
        
        metric.update(label, outputs)
    
    #Finish 1 epoch
    _, train_acc = metric.get()
    train_loss /= num_batch
    
    _, val_acc = test(finetune_net, val_data, ctx)
    train_history.append(val_acc)
    if len(train_history) > 1:
      diff = val_acc - train_history[epoch - 1]
      if (diff < stop_threshold):
        save_model(finetune_net, epoch)
        early_count += 1
      if (early_count == early_stop):
        break
    run_time = time.time() - tic
    print('[Epoch %d] Train-acc: %.3f, train-loss: %.3f | Val-acc: %.3f | time: %.3f'%
          (epoch, train_acc, train_loss, val_acc, run_time))
# Out:
# [Epoch 0] Train-acc: 0.547, train-loss: 1.037 | Val-acc: 0.888 | time: 7.710
# [Epoch 1] Train-acc: 0.804, train-loss: 0.498 | Val-acc: 0.868 | time: 7.999
# [Epoch 2] Train-acc: 0.811, train-loss: 0.484 | Val-acc: 0.888 | time: 7.759
# [Epoch 3] Train-acc: 0.851, train-loss: 0.424 | Val-acc: 0.904 | time: 8.087
# [Epoch 4] Train-acc: 0.846, train-loss: 0.385 | Val-acc: 0.883 | time: 7.828
# [Epoch 5] Train-acc: 0.887, train-loss: 0.337 | Val-acc: 0.909 | time: 7.884
# [Epoch 6] Train-acc: 0.866, train-loss: 0.312 | Val-acc: 0.904 | time: 7.840
# [Epoch 7] Train-acc: 0.811, train-loss: 0.434 | Val-acc: 0.898 | time: 7.611
# [Epoch 8] Train-acc: 0.841, train-loss: 0.368 | Val-acc: 0.924 | time: 7.667
# [Epoch 9] Train-acc: 0.841, train-loss: 0.393 | Val-acc: 0.919 | time: 7.783
# [Epoch 10] Train-acc: 0.874, train-loss: 0.290 | Val-acc: 0.924 | time: 7.940
# [Epoch 11] Train-acc: 0.889, train-loss: 0.311 | Val-acc: 0.924 | time: 7.899

# %%
_, test_acc = test(finetune_net, test_data, ctx)
print('[Finished] Test-acc: %.3f' % (test_acc))
# Out:
# [Finished] Test-acc: 0.876

# %%
net = finetune_net
save_model(net, 12)

# %%
bengal_train = 'cat_train/bengal_cat/bengal-5.jpg'
bengal = 'cat_test/bengal_cat/Bengal-Kitten.png'
bengal_val = "cat_val/bengal_cat/image0.jpeg"
munchkin = 'cat_test/munchkin_cat/25-1.jpg'
siamese = 'cat_test/siamese_cat/Siamese.png'
siamese_val = "cat_val/siamese_cat/image11.jpeg"


test_images = [bengal_train, bengal, bengal_val, munchkin, siamese, siamese_val]
expect_result = [0, 0, 0, 1, 2, 2]
test_result = []

# %%
for file in test_images:
    img_path = os.path.join(path, file)
    img = mx.image.imread(img_path)   
    img_t = transform_test(img)
    img_e = img_t.expand_dims(axis=0)
    pred = net(img_e)
    idx = nd.argmax(nd.softmax(pred), axis=1)
    test_result.append(idx.asscalar().astype('int'))
# Out:
# ---------------------------------------------------------------------------
# MXNetError                                Traceback (most recent call last)
# <ipython-input-16-2d61832109ed> in <module>()
#       4     img_t = transform_test(img)
#       5     img_e = img_t.expand_dims(axis=0)
# ----> 6     pred = net(img_e)
#       7     idx = nd.argmax(nd.softmax(pred), axis=1)
#       8     test_result.append(idx.asscalar().astype('int'))
#
# /usr/local/lib/python3.6/dist-packages/mxnet/gluon/block.py in __call__(self, *args)
#     546             hook(self, args)
#     547
# --> 548         out = self.forward(*args)
#     549
#     550         for hook in self._forward_hooks.values():
#
# /usr/local/lib/python3.6/dist-packages/mxnet/gluon/block.py in forward(self, x, *args)
#     913             with x.context as ctx:
#     914                 if self._active:
# --> 915                     return self._call_cached_op(x, *args)
#     916
#     917                 try:
#
# /usr/local/lib/python3.6/dist-packages/mxnet/gluon/block.py in _call_cached_op(self, *args)
#     819                     i._finish_deferred_init()
#     820                     cargs.append(i.data())
# --> 821         out = self._cached_op(*cargs)
#     822         if isinstance(out, NDArray):
#     823             out = [out]
#
# /usr/local/lib/python3.6/dist-packages/mxnet/_ctypes/ndarray.py in __call__(self, *args, **kwargs)
#     148             ctypes.byref(num_output),
#     149             ctypes.byref(output_vars),
# --> 150             ctypes.byref(out_stypes)))
#     151
#     152         if original_output is not None:
#
# /usr/local/lib/python3.6/dist-packages/mxnet/base.py in check_call(ret)
#     251     """
#     252     if ret != 0:
# --> 253         raise MXNetError(py_str(_LIB.MXGetLastError()))
#     254
#     255
#
# MXNetError: [07:08:57] src/imperative/cached_op.cc:916: Check failed: inputs[i]->ctx() == default_ctx (gpu(0) vs. cpu(0)) : CachedOp requires all inputs to live on the same context. But data is on cpu(0) while resnetv20_batchnorm0_gamma is on gpu(0)
# Stack trace:
#   [bt] (0) /usr/local/lib/python3.6/dist-packages/mxnet/libmxnet.so(+0x4b04cb) [0x7f2c28e204cb]
#   [bt] (1) /usr/local/lib/python3.6/dist-packages/mxnet/libmxnet.so(mxnet::CachedOp::Forward(std::shared_ptr<mxnet::CachedOp> const&, std::vector<mxnet::NDArray*, std::allocator<mxnet::NDArray*> > const&, std::vector<mxnet::NDArray*, std::allocator<mxnet::NDArray*> > const&)+0x4f8) [0x7f2c2afbc618]
#   [bt] (2) /usr/local/lib/python3.6/dist-packages/mxnet/libmxnet.so(MXInvokeCachedOp+0x4ab) [0x7f2c2aed15eb]
#   [bt] (3) /usr/local/lib/python3.6/dist-packages/mxnet/libmxnet.so(MXInvokeCachedOpEx+0x4f) [0x7f2c2aed1cef]
#   [bt] (4) /usr/lib/x86_64-linux-gnu/libffi.so.6(ffi_call_unix64+0x4c) [0x7f2c7bf22dae]
#   [bt] (5) /usr/lib/x86_64-linux-gnu/libffi.so.6(ffi_call+0x22f) [0x7f2c7bf2271f]
#   [bt] (6) /usr/lib/python3.6/lib-dynload/_ctypes.cpython-36m-x86_64-linux-gnu.so(_ctypes_callproc+0x2b4) [0x7f2c7c1365c4]
#   [bt] (7) /usr/lib/python3.6/lib-dynload/_ctypes.cpython-36m-x86_64-linux-gnu.so(+0x11c33) [0x7f2c7c136c33]
#   [bt] (8) /usr/bin/python3(_PyObject_FastCallKeywords+0x19c) [0x5aa6ec]

# %%
#Test if result is correct
assert(test_result == expect_result)

# %%
plt.imshow(img.asnumpy())

# %%
#Save trained model
def save_model(path = './trained_models', name ='resnet', net, epoch):
  f_name = os.path.join(path, name)
  net.export(f_name, epoch=epoch)

# %%
#Get classes by reading data to generate labels
a = ImageFolderDataset(val_path)

# %%
for idx, label in enumerate(a.synsets):
    print(idx, label)
# Out:
# 0 bengal_cat
# 1 munchkin_cat
# 2 persian_cat
# 3 siamese_cat

# %%
# !rm ./trained_models/resnet-0004.params

# %%
# !git config --global user.email "tmnguyen1403@gmail.com"

# %%
# !git config --global user.name "Minh Nguyen"

# %%
# !git add .ipynb_checkpoints/

# %%
# !git commit -m "Run with GPU(s) on Colab"
# Out:
# [master d3cc9f0] Run with GPU(s) on Colab
#  1 file changed, 1 insertion(+), 428 deletions(-)
#  rewrite .ipynb_checkpoints/FineTune_Siamese-checkpoint.ipynb (99%)

# %%
# !git push
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 6.17 KiB | 1.54 MiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/tmnguyen1403/cat_classification.git
#    56a94c5..d3cc9f0  master -> master
